# %%
import requests

key = 'e12be2ef03b4294b6b4ca0657423cbc6'
URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&targetDt=20190113&weekGb=0'
# response = requests.get(URL).json()
# recorded_at = response['boxOfficeResult']['showRange']
# response = response['boxOfficeResult']['weeklyBoxOfficeList']
# Out:
# {'boxOfficeResult': {'boxofficeType': '주간 박스오피스',
#   'showRange': '20190107~20190113',
#   'yearWeekTime': '201902',
#   'weeklyBoxOfficeList': [{'rnum': '1',
#     'rank': '1',
#     'rankInten': '8',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20184105',
#     'movieNm': '말모이',
#     'openDt': '2019-01-09',
#     'salesAmt': '8896251031',
#     'salesShare': '28.9',
#     'salesInten': '8025880431',
#     'salesChange': '922.1',
#     'salesAcc': '10070068631',
#     'audiCnt': '1033187',
#     'audiInten': '934370',
#     'audiChange': '945.6',
#     'audiAcc': '1185368',
#     'scrnCnt': '1203',
#     'showCnt': '24739'},
#    {'rnum': '2',
#     'rank': '2',
#     'rankInten': '19',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20176251',
#     'movieNm': '내안의 그놈',
#     'openDt': '2019-01-09',
#     'salesAmt': '6476584476',
#     'salesShare': '21.0',
#     'salesInten': '6432995476',
#     'salesChange': '14758.3',
#     'salesAcc': '6638709476',
#     'audiCnt': '744989',
#     'audiInten': '739766',
#     'audiChange': '14163.6',
#     'audiAcc': '765383',
#     'scrnCnt': '1041',
#     'showCnt': '15889'},
#    {'rnum': '3',
#     'rank': '3',
#     'rankInten': '-1',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20189463',
#     'movieNm': '주먹왕 랄프 2: 인터넷 속으로',
#     'openDt': '2019-01-03',
#     'salesAmt': '4580087005',
#     'salesShare': '14.9',
#     'salesInten': '-1528671143',
#     'salesChange': '-25.0',
#     'salesAcc': '10731240153',
#     'audiCnt': '583962',
#     'audiInten': '-169875',
#     'audiChange': '-22.5',
#     'audiAcc': '1342315',
#     'scrnCnt': '1185',
#     'showCnt': '22134'},
#    {'rnum': '4',
#     'rank': '4',
#     'rankInten': '-3',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20180290',
#     'movieNm': '아쿠아맨',
#     'openDt': '2018-12-19',
#     'salesAmt': '3280232985',
#     'salesShare': '10.6',
#     'salesInten': '-8438801763',
#     'salesChange': '-72.0',
#     'salesAcc': '43125562814',
#     'audiCnt': '376349',
#     'audiInten': '-963871',
#     'audiChange': '-71.9',
#     'audiAcc': '4920735',
#     'scrnCnt': '1086',
#     'showCnt': '17974'},
#    {'rnum': '5',
#     'rank': '5',
#     'rankInten': '49',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20183915',
#     'movieNm': '극장판 공룡메카드: 타이니소어의 섬',
#     'openDt': '2019-01-10',
#     'salesAmt': '2230689440',
#     'salesShare': '7.2',
#     'salesInten': '2226081440',
#     'salesChange': '48309.1',
#     'salesAcc': '2236575440',
#     'audiCnt': '289219',
#     'audiInten': '288707',
#     'audiChange': '56388.1',
#     'audiAcc': '289873',
#     'scrnCnt': '763',
#     'showCnt': '7597'},
#    {'rnum': '6',
#     'rank': '6',
#     'rankInten': '-2',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20185485',
#     'movieNm': '보헤미안 랩소디',
#     'openDt': '2018-10-31',
#     'salesAmt': '1520514090',
#     'salesShare': '4.9',
#     'salesInten': '-2777805660',
#     'salesChange': '-64.6',
#     'salesAcc': '84970758385',
#     'audiCnt': '175249',
#     'audiInten': '-317008',
#     'audiChange': '-64.4',
#     'audiAcc': '9785643',
#     'scrnCnt': '653',
#     'showCnt': '8554'},
#    {'rnum': '7',
#     'rank': '7',
#     'rankInten': '20',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20184574',
#     'movieNm': '그린 북',
#     'openDt': '2019-01-09',
#     'salesAmt': '821545524',
#     'salesShare': '2.7',
#     'salesInten': '793530924',
#     'salesChange': '2832.6',
#     'salesAcc': '889374224',
#     'audiCnt': '92682',
#     'audiInten': '89768',
#     'audiChange': '3080.6',
#     'audiAcc': '99569',
#     'scrnCnt': '398',
#     'showCnt': '4521'},
#    {'rnum': '8',
#     'rank': '8',
#     'rankInten': '-3',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20186281',
#     'movieNm': '범블비',
#     'openDt': '2018-12-25',
#     'salesAmt': '518826110',
#     'salesShare': '1.7',
#     'salesInten': '-3112095215',
#     'salesChange': '-85.7',
#     'salesAcc': '13026874637',
#     'audiCnt': '63391',
#     'audiInten': '-370566',
#     'audiChange': '-85.4',
#     'audiAcc': '1553491',
#     'scrnCnt': '632',
#     'showCnt': '5383'},
#    {'rnum': '9',
#     'rank': '9',
#     'rankInten': '-6',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20170658',
#     'movieNm': 'PMC: 더 벙커',
#     'openDt': '2018-12-26',
#     'salesAmt': '488207980',
#     'salesShare': '1.6',
#     'salesInten': '-4634378997',
#     'salesChange': '-90.5',
#     'salesAcc': '13976496874',
#     'audiCnt': '57525',
#     'audiInten': '-536249',
#     'audiChange': '-90.3',
#     'audiAcc': '1665204',
#     'scrnCnt': '670',
#     'showCnt': '5991'},
#    {'rnum': '10',
#     'rank': '10',
#     'rankInten': '-4',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20175547',
#     'movieNm': '스윙키즈',
#     'openDt': '2018-12-19',
#     'salesAmt': '278702060',
#     'salesShare': '0.9',
#     'salesInten': '-1651955490',
#     'salesChange': '-85.6',
#     'salesAcc': '12026480662',
#     'audiCnt': '34868',
#     'audiInten': '-197987',
#     'audiChange': '-85.0',
#     'audiAcc': '1462874',
#     'scrnCnt': '510',
#     'showCnt': '2768'}]}}

# %%
import requests

key = 'e12be2ef03b4294b6b4ca0657423cbc6'
URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&targetDt=20190113&weekGb=0'
response = requests.get(URL).json()
recorded_at = response['boxOfficeResult']['showRange']
response = response['boxOfficeResult']['weeklyBoxOfficeList']

# %%
# results = {
#     response[0]['rank']: response[0]['movieNm']
#     response[1]['rank']: response[1]['movieNm']
#     .
#     .
#     .
# }
# Out:
#   File "<ipython-input-8-9a959ede37ae>", line 3
#     response[1]['rank']: response[1]['movieNm']
#            ^
# SyntaxError: invalid syntax

# %%
# results = {}
# l = []
# results = {response[0]['rank']: response[0]['movieNm']}    
# title = results[response[0]['rank']]

# %%
# ln = [ movie_code, title, audience, recorded_at]

# l1 = []
# results = {
#     'movie_code': response[0]['movieCd'],
#     'title': response[0]['movieNm'],
#     'audience': response[0]['audiAcc'],
#     'recorded_at': recorded_at
# }
# movie_code = results['movie_code']
# title = results['title']
# audience = results['audience']
# recorded_at = results['recorded_at']
# l1.append(movie_code)
# l1.append(title)
# l1.append(audience)
# l1.append(recorded_at[9:])
# print(l1)
# Out:
# ['20184105', '말모이', '1185368', '20190113']

# %%
import requests
import datetime
start_date = datetime.datetime(20181111)

key = 'e12be2ef03b4294b6b4ca0657423cbc6'
URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&targetDt=20190113&weekGb=0'
response = requests.get(URL).json()
recorded_at = response['boxOfficeResult']['showRange']
response = response['boxOfficeResult']['weeklyBoxOfficeList']



for i in range(10):
    boxoffice = []
    results = {
        'movie_code': response[i]['movieCd'],
        'title': response[i]['movieNm'],
        'audience': response[i]['audiAcc'],
        'recorded_at': recorded_at
    }
#     movie_code = results['movie_code']
#     title = results['title']
#     audience = results['audience']
#     recorded_at = results['recorded_at']
    boxoffice.append(results['movie_code'])
    boxoffice.append(results['title'])
    boxoffice.append(results['audience'])
    boxoffice.append(results['recorded_at'][9:])
    print(boxoffice)
# Out:
# ['20184105', '말모이', '1185368', '20190113']
# ['20176251', '내안의 그놈', '765383', '20190113']
# ['20189463', '주먹왕 랄프 2: 인터넷 속으로', '1342315', '20190113']
# ['20180290', '아쿠아맨', '4920735', '20190113']
# ['20183915', '극장판 공룡메카드: 타이니소어의 섬', '289873', '20190113']
# ['20185485', '보헤미안 랩소디', '9785643', '20190113']
# ['20184574', '그린 북', '99569', '20190113']
# ['20186281', '범블비', '1553491', '20190113']
# ['20170658', 'PMC: 더 벙커', '1665204', '20190113']
# ['20175547', '스윙키즈', '1462874', '20190113']

# %%
import datetime
import requests
import csv

movie_dict = []

start_date = datetime.datetime(2018,11,11)
for i in range(10):
    t = start_date + timedelta(days=7 * i)
    target = t.strftime('%Y%m%d')
    
    key = 'e12be2ef03b4294b6b4ca0657423cbc6'
    URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&targetDt={target}&weekGb=0'
    response = requests.get(URL).json()
    recorded_at = response['boxOfficeResult']['showRange']
    response = response['boxOfficeResult']['weeklyBoxOfficeList']



    for i in range(10):
        boxoffice = []
        results = {
            'movie_code': response[i]['movieCd'],
            'title': response[i]['movieNm'],
            'audience': response[i]['audiAcc'],
            'recorded_at': recorded_at
        }
        if response[i]['movieCd'] not in movie_dict:     
        
            movie_dict.append(results['movie_code'])
            movie_dict.append(results['title'])
            movie_dict.append(results['audience'])
            movie_dict.append(results['recorded_at'][9:])
            boxoffice.append(results['movie_code'])
            boxoffice.append(results['title'])
            boxoffice.append(results['audience'])
            boxoffice.append(results['recorded_at'][9:])
        else:
            pass
a = len(movie_dict) / 4

for i in range(int(a)):    
    a = movie_dict[4 * i: 4 * (i + 1)]
    f = open('boxoffice.csv', 'a+', encoding='utf-8', newline='')
    writer = csv.writer(f)

    writer.writerow(
        a
    )

    f.close

# %%
from datetime import datetime, timedelta
import requests
import csv



start_date = datetime(2018,11,11)
for i in range(10):
    t = start_date + timedelta(days=7 * i)
    target = t.strftime('%Y%m%d')
    
    for k in range(10):
        key = 'e12be2ef03b4294b6b4ca0657423cbc6'
        URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&targetDt={target}&weekGb=0'
        response = requests.get(URL).json()
        response = response['boxOfficeResult']['weeklyBoxOfficeList']
        moviecode = response[k]['movieCd']
        print(moviecode)
# Out:
# 20177538
# 20185485
# 20170513
# 20181171
# 20174981

# %%
from datetime import datetime, timedelta
import requests
import csv

cl = []

start_date = datetime(2018,11,11)
for i in range(10):
    t = start_date + timedelta(days=7 * i)
    target = t.strftime('%Y%m%d')
        
    key = 'e12be2ef03b4294b6b4ca0657423cbc6'
    URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&targetDt={target}&weekGb=0'
    response = requests.get(URL).json()
    response = response['boxOfficeResult']['weeklyBoxOfficeList']
    
    for k in range(10):
        moviecode = response[k]['movieCd']
        cl.append(moviecode)
        
cl = list(set(cl))
movie_info = []  
for moviecode in cl:
    key = 'e12be2ef03b4294b6b4ca0657423cbc6'
    URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo?key={key}&movieCd={moviecode}'
    response = requests.get(URL).json()
    response = response['movieInfoResult']['movieInfo']
        
print(response)
# Out:
# {'movieCd': '20181404', 'movieNm': '벽 속에 숨은 마법시계', 'movieNmEn': 'The house with a clock in its walls', 'movieNmOg': '', 'showTm': '105', 'prdtYear': '2018', 'openDt': '20181031', 'prdtStatNm': '개봉', 'typeNm': '장편', 'nations': [{'nationNm': '미국'}], 'genres': [{'genreNm': '판타지'}, {'genreNm': '공포(호러)'}, {'genreNm': '미스터리'}, {'genreNm': 'SF'}, {'genreNm': '스릴러'}], 'directors': [{'peopleNm': '일라이 로스', 'peopleNmEn': 'Eli Roth'}], 'actors': [{'peopleNm': '잭 블랙', 'peopleNmEn': 'Jack Black', 'cast': '', 'castEn': ''}, {'peopleNm': '케이트 블란쳇', 'peopleNmEn': 'Cate Blanchett', 'cast': '', 'castEn': ''}, {'peopleNm': '오웬 바카로', 'peopleNmEn': 'Owen Vaccaro', 'cast': '', 'castEn': ''}], 'showTypes': [{'showTypeGroupNm': '2D', 'showTypeNm': '디지털'}, {'showTypeGroupNm': '4D', 'showTypeNm': '4D'}], 'companys': [{'companyCd': '20102327', 'companyNm': 'CGV아트하우스', 'companyNmEn': 'CGV ARTHOUSE', 'companyPartNm': '배급사'}, {'companyCd': '20110854', 'companyNm': '씨제이이앤엠(주)', 'companyNmEn': 'CJ ENM Corp.', 'companyPartNm': '수입사'}], 'audits': [{'auditNo': '2018-MF01769', 'watchGradeNm': '전체관람가'}], 'staffs': []}

# %%
from datetime import datetime, timedelta
import requests
import csv

cl = []

start_date = datetime(2018,11,11)
for i in range(10):
    t = start_date + timedelta(days=7 * i)
    target = t.strftime('%Y%m%d')
        
    key = 'e12be2ef03b4294b6b4ca0657423cbc6'
    URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&targetDt={target}&weekGb=0'
    response = requests.get(URL).json()
    response = response['boxOfficeResult']['weeklyBoxOfficeList']
    
    for k in range(10):
        moviecode = response[k]['movieCd']
        cl.append(moviecode)
        
print(cl)
# Out:
# ['20177538', '20185485', '20170513', '20181171', '20174981', '20010291', '20179006', '20181404', '20180523', '20182693', '20176814', '20185485', '20177538', '20183050', '20170513', '20184481', '20181171', '20182935', '20186822', '20189869', '20185485', '20184481', '20176814', '20177538', '20183050', '20183073', '20181171', '20182935', '20182669', '20186822', '20177552', '20185485', '20184481', '20177538', '20181905', '20176814', '20183073', '20181171', '20183007', '20182966', '20177552', '20185485', '20179230', '20189843', '20178825', '20183745', '20184481', '20177538', '20181905', '20176814', '20185485', '20177552', '20179230', '20183238', '20189843', '20182082', '20175547', '20178825', '20183745', '20177538', '20180290', '20168773', '20175547', '20185485', '20182421', '20177552', '20183238', '20179230', '20183479', '20183375', '20180290', '20186281', '20170658', '20185485', '20168773', '20175547', '20183785', '20182421', '20183479', '20183238', '20180290', '20189463', '20170658', '20185485', '20186281', '20175547', '20183785', '20184187', '20184105', '20182421', '20184105', '20176251', '20189463', '20180290', '20183915', '20185485', '20184574', '20186281', '20170658', '20175547']

# %%
from datetime import datetime, timedelta
import requests
import csv

cl = []

start_date = datetime(2018,11,11)
for i in range(10):
    t = start_date + timedelta(days=7 * i)
    target = t.strftime('%Y%m%d')
        
    key = 'e12be2ef03b4294b6b4ca0657423cbc6'
    URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&targetDt={target}&weekGb=0'
    response = requests.get(URL).json()
    response = response['boxOfficeResult']['weeklyBoxOfficeList']
    
    for k in range(10):
        moviecode = response[k]['movieCd']
        cl.append(moviecode)

cl = list(set(cl))

 

for movieCd in cl:
    movie_info = [] 
    key = 'e12be2ef03b4294b6b4ca0657423cbc6'
    URL = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo?key={key}&movieCd={movieCd}'
    response = requests.get(URL).json()
    response = response['movieInfoResult']['movieInfo']   
            
    movieCd = response['movieCd']
    movieNm = response['movieNm']
    movieNmEn = response['movieNmEn']
    movieNmOg = response['movieNmOg']
    openDt = response['openDt']
    showTm = response['showTm']
    genreNm = response['genres'][0]['genreNm']
    peopleNm = response['directors'][0]['peopleNm']
    watchGradeNm = response['audits'][0]['watchGradeNm']
    
    if len(response['actors']) == 0:
        actor1 = ''
        actor2 = ''
        actor3 = ''
    elif len(response['actors']) == 1:
        actor1 = response['actors'][0]['peopleNm']
        actor2 = ''
        actor3 = ''
    elif len(response['actors']) == 2:
        actor1 = response['actors'][0]['peopleNm']
        actor2 = response['actors'][1]['peopleNm']
        actor3 = ''
    elif len(response['actors']) >= 3:
        actor1 = response['actors'][0]['peopleNm']
        actor2 = response['actors'][1]['peopleNm']
        actor3 = response['actors'][2]['peopleNm']
    
    movie_info.append(movieCd)
    movie_info.append(movieNm)
    movie_info.append(movieNmEn)
    movie_info.append(movieNmOg)
    movie_info.append(openDt)
    movie_info.append(showTm)
    movie_info.append(genreNm)
    movie_info.append(peopleNm)
    movie_info.append(watchGradeNm)
    movie_info.append(actor1)
    movie_info.append(actor2)
    movie_info.append(actor3)
    
    print(movie_info)
#     f = open('movie.csv', 'a+', encoding='utf-8', newline='')
#     writer = csv.writer(f)

#     writer.writerow(
#         movie_info
#     )
    
#     f.close
# Out:
# ['20183479', '20175547', '20189463', '20184574', '20182966', '20181171', '20183050', '20176251', '20183007', '20186822', '20189843', '20179006', '20182082', '20182421', '20183375', '20180290', '20177552', '20185485', '20183073', '20181404', '20182669', '20170513', '20010291', '20179230', '20180523', '20186281', '20183785', '20174981', '20177538', '20183238', '20182693', '20176814', '20184187', '20183915', '20184481', '20183745', '20168773', '20184105', '20170658', '20178825', '20181905', '20182935', '20189869']
# ['20183479', '극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~', 'Crayon Shin-chan: Burst Serving! Kung Fu Boys - Ramen Rebellion', '', '20181219', '103', '애니메이션', '타카하시 와타루', '전체관람가', '박영남', '강희선', '김환진']
# ['20175547', '스윙키즈', 'Swing Kids', '', '20181219', '133', '드라마', '강형철', '12세이상관람가', '도경수', '박혜수', '자레드 그라임스']
# ['20189463', '주먹왕 랄프 2: 인터넷 속으로', 'Ralph Breaks the Internet', '', '20190103', '112', '애니메이션', '리치 무어', '전체관람가', '존 C. 라일리', '사라 실버맨', '맨디 무어']
# ['20184574', '그린 북', 'Green Book', '', '20190109', '130', '드라마', '피터 패럴리', '12세이상관람가', '비고 모텐슨', '마허샬라 알리', '']
# ['20182966', '투 프렌즈', 'TWO TAILS', '', '20181129', '74', '애니메이션', '빅터 아즈에프', '전체관람가', '', '', '']
# ['20181171', '바울', 'Paul, Apostle Of Christ', '', '20181031', '107', '드라마', '앤드류 하얏트', '15세이상관람가', '제임스 폴크너', '제임스 카비젤', '']
# ['20183050', '번 더 스테이지: 더 무비', 'Burn the Stage: the Movie', '', '20181115', '82', '기타', '박준수', '전체관람가', '김남준', '김석진', '민윤기']
# ['20176251', '내안의 그놈', 'Inside me', '', '20190109', '122', '판타지', '강효진', '15세이상관람가', '박성웅', '진영', '라미란']
# ['20183007', '거미줄에 걸린 소녀', 'THE GIRL IN THE SPIDER’S WEB', '', '20181128', '115', '액션', '페드 알바레즈', '15세이상관람가', '클레어 포이', '실비아 획스', '스베리르 구드나손']
# ['20186822', '너의 췌장을 먹고 싶어', 'I want to eat your pancreas', '君の膵臓をたべたい', '20181115', '109', '애니메이션', '우시지마 신이치로', '12세이상관람가', '타카스기 마히로', '린', '후지이 유키요']
# ['20189843', '호두까기 인형과 4개의 왕국', 'The Nutcracker and the Four Realms', '', '20181206', '99', '판타지', '라세 할스트롬', '전체관람가', '키이라 나이틀리', '매켄지 포이', '헬렌 미렌']
# ['20179006', '여곡성', 'The Wrath', '', '20181108', '94', '공포(호러)', '유영선', '15세이상관람가', '홍예리', '서영희', '손나은']
# ['20182082', '부탁 하나만 들어줘', 'A Simple Favor', '', '20181212', '116', '스릴러', '폴 페이그', '청소년관람불가', '블레이크 라이블리', '안나 켄드릭', '헨리 골딩']
# ['20182421', '그린치', 'The Grinch', '', '20181219', '89', '애니메이션', '스콧 모시어', '전체관람가', '베네딕트 컴버배치', '', '']
# ['20183375', '극장판 포켓몬스터 모두의 이야기', 'Pokemon the Movie: The Power of Us', '劇場版ポケットモンスター みんなの物語', '20181219', '98', '애니메이션', '야지마 테츠오', '전체관람가', '', '', '']
# ['20180290', '아쿠아맨', 'AQUAMAN', '', '20181219', '143', '액션', '제임스 완', '12세이상관람가', '제이슨 모모아', '앰버 허드', '니콜 키드먼']
# ['20177552', '국가부도의 날', 'Default', '', '20181128', '114', '드라마', '최국희', '12세이상관람가', '김혜수', '유아인', '허준호']
# ['20185485', '보헤미안 랩소디', 'Bohemian Rhapsody', '', '20181031', '134', '드라마', '브라이언 싱어', '12세이상관람가', '레미 맬렉', '조셉 마젤로', '마이크 마이어스']
# ['20183073', '베일리 어게인', "A Dog's Purpose", '', '20181122', '100', '어드벤처', '라세 할스트롬', '전체관람가', '조시 게드', '데니스 퀘이드', '브릿 로버트슨']
# ['20181404', '벽 속에 숨은 마법시계', 'The house with a clock in its walls', '', '20181031', '105', '판타지', '일라이 로스', '전체관람가', '잭 블랙', '케이트 블란쳇', '오웬 바카로']
# ['20182669', '툴리', 'TULLY', '', '20181122', '95', '드라마', '제이슨 라이트맨', '15세이상관람가', '샤를리즈 테론', '맥켄지 데이비스', '마크 듀플라스']
# ['20170513', '동네사람들', '', '', '20181107', '99', '액션', '임진순', '15세이상관람가', '마동석', '김새론', '이상엽']
# ['20010291', '해리포터와 마법사의 돌', 'Harry Potter And The Socrerers Stone', '', '20011213', '152', '가족', '크리스 콜럼버스', '전체관람가', '다니엘 래드클리프', '엠마 왓슨', '루퍼트 그린트']
# ['20179230', '도어락', 'Door Lock', '', '20181205', '101', '스릴러', '이권', '15세이상관람가', '공효진', '김예원', '김성오']
# ['20180523', '스타 이즈 본', 'A Star Is Born', '', '20181009', '135', '드라마', '브래들리 쿠퍼', '15세이상관람가', '브래들리 쿠퍼', '레이디 가가', '샘 엘리엇']
# ['20186281', '범블비', 'Bumblebee', '', '20181225', '113', '액션', '트래비스 나이트', '12세이상관람가', '헤일리 스테인펠드', '파멜라 애들론', '존 시나']
# ['20183785', '점박이 한반도의 공룡2 : 새로운 낙원', '', '', '20181225', '93', '애니메이션', '한상호', '전체관람가', '박희순', '라미란', '김성균']
# ['20174981', '창궐', 'Rampant', '', '20181025', '121', '사극', '김성훈', '15세이상관람가', '현빈', '장동건', '조우진']
# ['20177538', '완벽한 타인', 'Intimate Strangers', '', '20181031', '115', '드라마', '이재규', '15세이상관람가', '유해진', '조진웅', '이서진']
# ['20183238', '스파이더맨: 뉴 유니버스', 'Spider-Man: Into the Spider-Verse', '', '20181212', '116', '애니메이션', '밥 퍼시케티', '12세이상관람가', '샤메익 무어', '헤일리 스테인펠드', '니콜라스 케이지']
# ['20182693', '구스범스: 몬스터의 역습', 'Goosebumps 2: Haunted Halloween', '', '20181107', '89', '판타지', '아리 산델', '12세이상관람가', '잭 블랙', '켄 정', '']
# ['20176814', '신비한 동물들과 그린델왈드의 범죄', 'Fantastic Beasts: The Crimes of Grindelwald', 'FANTASTIC BEASTS THE CRIMES OF GRINDELWALD', '20181114', '133', '판타지', '데이빗 예이츠', '12세이상관람가', '에디 레드메인', '캐서린 워터스턴', '앨리슨 수돌']
# ['20184187', '언니', 'No Mercy', '', '20190101', '93', '액션', '임경택', '청소년관람불가', '이시영', '박세완', '이준혁']
# ['20183915', '극장판 공룡메카드: 타이니소어의 섬', '', '', '20190110', '70', '애니메이션', '최신규', '전체관람가', '', '', '']
# ['20184481', '성난황소', 'Unstoppable', '', '20181122', '115', '범죄', '김민호', '15세이상관람가', '마동석', '송지효', '김성오']
# ['20183745', '런닝맨 : 풀룰루의 역습', 'Running Man', '', '20181205', '66', '애니메이션', '윤준상', '전체관람가', '김서영', '권창욱', '엄상현']
# ['20168773', '마약왕', 'The Drug King', '', '20181219', '139', '범죄', '우민호', '청소년관람불가', '송강호', '조정석', '배두나']
# ['20184105', '말모이', 'MAL·MO·E: The Secret Mission', '', '20190109', '135', '드라마', '엄유나', '12세이상관람가', '유해진', '윤계상', '김홍파']
# ['20170658', 'PMC: 더 벙커', 'Take Point', '', '20181226', '124', '액션', '김병우', '15세이상관람가', '하정우', '이선균', '제니퍼 엘']
# ['20178825', '모털 엔진', 'Mortal Engines', '', '20181205', '128', '액션', '크리스찬 리버스', '12세이상관람가', '헤라 힐마', '로버트 시한', '휴고 위빙']
# ['20181905', '후드', 'Robin Hood', '', '20181128', '116', '어드벤처', '오토 바서스트', '12세이상관람가', '태런 에저튼', '제이미 폭스', '벤 멘델슨']
# ['20182935', '출국', 'Unfinished', '', '20181114', '104', '드라마', '노규엽', '15세이상관람가', '이범수', '연우진', '박혁권']
# ['20189869', '해피 투게더', 'Happy Together', '', '20181115', '110', '드라마', '김정환', '12세이상관람가', '박성웅', '송새벽', '최로운']

# %%
import requests
import urllib.request
import csv
import json

naver_URI = 'https://openapi.naver.com/v1/search/movie.json?query='
client_id = 'FaSdalhj1Twe1bDOc9uO'
client_secret = 'Fjx3tc_Alv'
headers = {'X-Naver-Client-Id' : client_id, 'X-Naver-Client-Secret': client_secret}

cl
